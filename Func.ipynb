# %%
# This code needs to be in the same cell, or the first cell needs to be run before the second cell
album_rating = [10.0,8.8,9.2,7.5,7.8,7.6,8.0,8.4]
album_rating
# Out:
# [10.0, 8.8, 9.2, 7.5, 7.8, 7.6, 8.0, 8.4]

# %%
# Way 1
sorted_album_rating = sorted(album_rating)
sorted_album_rating
# Out:
# [7.5, 7.6, 7.8, 8.0, 8.4, 8.8, 9.2, 10.0]

# %%
# Way 2
album_rating.sort()
album_rating
# Out:
# [7.5, 7.6, 7.8, 8.0, 8.4, 8.8, 9.2, 10.0]

# %%
def add(a):
  b=a+1
  return(b)

# %%
add(1)
# Out:
# 2

# %%
# Without explain

help(add)
# Out:
# Help on function add in module __main__:
#
# add(a)

# %%
# With explain
def add_v2(a):
    """
    add 1 to a
    Input: a (int)
    Output: a+1 (int)
    """
    b=a+1
    return(b)

# %%
help(add_v2)
# Out:
# Help on function add_v2 in module __main__:
#
# add_v2(a)
#     add 1 to a
#     Input: a (int)
#     Output: a+1 (int)

# %%
stuff = [8.5,7.3,8.1]
for i,e in enumerate(stuff):
  print(i,e)
# Out:
# 0 8.5
# 1 7.3
# 2 8.1

# %%
# e 可以替換但不能是 i

stuff = [8.5,7.3,8.1]
for i,i in enumerate(stuff):
  print(i,i)
# Out:
# 8.5 8.5
# 7.3 7.3
# 8.1 8.1

# %%
def multiply(a, b):
    """
    This function multiplies two numbers.
    Input: a (number), b (number)
    Output: Product of a and b
    """
    print(a * b)
multiply(2,6)
# Out:
# 12

# %%
# Show how to work

help(multiply)
# Out:
# Help on function multiply in module __main__:
#
# multiply(a, b)
#     This function multiplies two numbers.
#     Input: a (number), b (number)
#     Output: Product of a and b

# %%
L=[1,3,2]

sorted(L)
# Out:
# [1, 2, 3]
