# %%
# Leetcode 原始格式

class Solution:

    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:


        dummy_head = ListNode('@')
        iterator = dummy_head

        carry_in = 0

        # add digit by digit
        while l1 or l2:

            val_1 = l1.val if l1 else 0
            val_2 = l2.val if l2 else 0

            # compute digit sum and carry-in
            carry_in, digit_sum = divmod( val_1 + val_2 + carry_in, 10)

            iterator.next = ListNode( digit_sum )
            iterator = iterator.next

            l1 = l1.next if l1 else None
            l2 = l2.next if l2 else None

        # handle for the carry-in on most significant digit
        if carry_in:
            iterator.next = ListNode( carry_in )

        return dummy_head.next

# %%
# Gemini 更改為 Colab 的格式

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def list_to_linked_list(lst):
    if not lst:
        return None
    head = ListNode(lst[0])
    curr = head
    for val in lst[1:]:
        curr.next = ListNode(val)
        curr = curr.next
    return head

class Solution:

    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:


        dummy_head = ListNode('@')
        iterator = dummy_head

        carry_in = 0

        # add digit by digit
        while l1 or l2:

            val_1 = l1.val if l1 else 0
            val_2 = l2.val if l2 else 0

            # compute digit sum and carry-in
            carry_in, digit_sum = divmod( val_1 + val_2 + carry_in, 10)

            iterator.next = ListNode( digit_sum )
            iterator = iterator.next

            l1 = l1.next if l1 else None
            l2 = l2.next if l2 else None

        # handle for the carry-in on most significant digit
        if carry_in:
            iterator.next = ListNode( carry_in )

        return dummy_head.next


# 建立 Solution 物件
solution = Solution()

# 輸入 case 1
l1 = list_to_linked_list([2, 4, 3])
l2 = list_to_linked_list([5, 6, 4])
results = solution.addTwoNumbers(l1, l2)

# 顯示輸出
while results:
    print(results.val, end=" ")
    results = results.next
# Out:
# 7 0 8

# %%
# 第一次嘗試錯誤版

from typing import List

class Solution:

    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:


        dummy_head = ListNode('@')
        iterator = dummy_head

        carry_in = 0

        # add digit by digit
        while l1 or l2:

            val_1 = l1.val if l1 else 0
            val_2 = l2.val if l2 else 0

            # compute digit sum and carry-in
            carry_in, digit_sum = divmod( val_1 + val_2 + carry_in, 10)

            iterator.next = ListNode( digit_sum )
            iterator = iterator.next

            l1 = l1.next if l1 else None
            l2 = l2.next if l2 else None

        # handle for the carry-in on most significant digit
        if carry_in:
            iterator.next = ListNode( carry_in )

        return dummy_head.next

# 建立一個 Solution 物件
solution = Solution()

# 輸入 case 1
l1 = [2,4,3]
l2 = [5,6,4]
results = solution.addTwoNumbers(l1, l2)

print(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5c2b9fbecf7f> in <cell line: 5>()
#       3 from typing import List
#       4
# ----> 5 class Solution:
#       6
#       7     def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
#
# <ipython-input-3-5c2b9fbecf7f> in Solution()
#       5 class Solution:
#       6
# ----> 7     def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
#       8
#       9
#
# NameError: name 'ListNode' is not defined
