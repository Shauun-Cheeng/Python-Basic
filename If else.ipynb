# %%
# Error 尚未轉換成int

print("Input your age!")
age = input()

if (age ==18):
  print("Go to room A!")
elif (age >18):
  print("Go to room B!")
else:
  print("Go to room C!")
# Out:
# Input your age!
# 19
# Go to room B!

# %%
print("Input your age!")
age = int(input()) # Cast the input to an integer

if (age ==18):
  print("Go to room A!")
elif (age >18):
  print("Go to room B!")
else:
  print("Go to room C!")
# Out:
# Input your age!
# 18
# Go to room A!
