# %%
dic = {"aa":30,"gg":90}
dic
# Out:
# {'aa': 30, 'gg': 90}

# %%
dic["kk"]=90
dic
# Out:
# {'aa': 30, 'gg': 90, 'kk': 90}

# %%
dic["yy"]=70
dic["tt"]=80
del dic["aa"]
dic
# Out:
# {'gg': 90, 'kk': 90, 'yy': 70, 'tt': 80}

# %%
dic.keys()
# Out:
# dict_keys(['gg', 'kk', 'yy', 'tt'])

# %%
list(dic.keys())
# Out:
# ['gg', 'kk', 'yy', 'tt']

# %%
dic.values()
# Out:
# dict_values([90, 90, 70, 80])

# %%
type(dic)
# Out:
# dict

# %%
dic['tt']
# Out:
# 80
