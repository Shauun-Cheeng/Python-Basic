# %%
x = [1,4,5,4,4,7,8,1,1,5]
x
# Out:
# [1, 4, 5, 4, 4, 7, 8, 1, 1, 5]

# %%
set(x)
# Out:
# {1, 4, 5, 7, 8}

# %%
type(x)
# Out:
# list

# %%
y = set(x)

# %%
type(y)
# Out:
# set

# %%
y
# Out:
# {1, 4, 5, 7, 8}

# %%
y.add(2)
y
# Out:
# {1, 2, 4, 5, 7, 8}
